# %% [markdown]
# # **1. Import Library**

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

# %% [markdown]
#  # **2. Masukkan Dataset**

# %%
data3 = {
    "Temperature": [14.0,39.0,18.0,38.0,27.0,32.0,7.0,3.0,8.0,28.0],
    "Humidity": [73,96,83,83,74,55,97,85,73,74],
    "Wind": [9.5,8.5,7.0,1.5,11.0,3.5,6.0,8.0,4.5,8.5],
    "Precip": [82.0,71.0,16.0,82.0,66.0,22.0,96.0,68.0,22.0,107.0],
    "Cloud": ["partly cloudy","partly cloudy","clear","clear",
              "overcast","overcast","partly cloudy","overcast","overcast","clear"],
    "Pressure": [1010.82,1011.43,1018.72,1026.25,990.67,1010.03,986.42,984.46,999.46,1012.13],
    "UV": [2,7,5,7,2,1,3,1,5,6],
    "Season": ["Winter","Spring","Spring","Spring","Winter","Summer",
               "Winter","Winter","Winter","Winter"],
    "Visibility": [3.5,10.0,5.5,1.0,2.5,5.0,3.5,1.0,3.5,7.5],
    "Location": ["inland","inland","mountain","coastal","mountain","inland",
                 "inland","inland","mountain","coastal"],
    "Weather": ["Rainy","Cloudy","Rainy","Sunny","Sunny",
                "Cloudy","Snowy","Snowy","Snowy","Sunny"]
}

df3 = pd.DataFrame(data3)
df3
# Out:
#    Temperature  Humidity  Wind  Precip          Cloud  Pressure  UV  Season  \
# 0         14.0        73   9.5    82.0  partly cloudy   1010.82   2  Winter
# 1         39.0        96   8.5    71.0  partly cloudy   1011.43   7  Spring
# 2         18.0        83   7.0    16.0          clear   1018.72   5  Spring
# 3         38.0        83   1.5    82.0          clear   1026.25   7  Spring
# 4         27.0        74  11.0    66.0       overcast    990.67   2  Winter
# 5         32.0        55   3.5    22.0       overcast   1010.03   1  Summer
# 6          7.0        97   6.0    96.0  partly cloudy    986.42   3  Winter
# 7          3.0        85   8.0    68.0       overcast    984.46   1  Winter
# 8          8.0        73   4.5    22.0       overcast    999.46   5  Winter
# 9         28.0        74   8.5   107.0          clear   1012.13   6  Winter
#
#    Visibility  Location Weather
# 0         3.5    inland   Rainy
# 1        10.0    inland  Cloudy
# 2         5.5  mountain   Rainy
# 3         1.0   coastal   Sunny
# 4         2.5  mountain   Sunny
# 5         5.0    inland  Cloudy
# 6         3.5    inland   Snowy
# 7         1.0    inland   Snowy
# 8         3.5  mountain   Snowy
# 9         7.5   coastal   Sunny

# %% [markdown]
#  # **3. Encoding Kolom Kategori (One-Hot Encoding)**

# %%
df3_encoded = pd.get_dummies(df3, columns=["Cloud","Season","Location"])

# %% [markdown]
#  # **4. Pisahkan Fitur dan Label**

# %%
X = df3_encoded.drop("Weather", axis=1)
y = df3_encoded["Weather"]

# %% [markdown]
#  # **5. Normalisasi Data Numerik**

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # **6. Split Data Training dan Testing (70:30)**

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.3, random_state=42
)

# %% [markdown]
# # **7. Membangun Model KNN**

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# # **8. Prediksi Menggunakan Data Testing**

# %%
y_pred = knn.predict(X_test)

# %% [markdown]
#  # **9. Evaluasi Model (Confusion Matrix, Accuracy, Report)**

# %%
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
print("\nAkurasi:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Confusion Matrix:
#  [[0 2 0]
#  [0 0 0]
#  [0 1 0]]
#
# Akurasi: 0.0
#
# Classification Report:
#                precision    recall  f1-score   support
#
#       Cloudy       0.00      0.00      0.00       2.0
#        Rainy       0.00      0.00      0.00       0.0
#        Snowy       0.00      0.00      0.00       1.0
#
#     accuracy                           0.00       3.0
#    macro avg       0.00      0.00      0.00       3.0
# weighted avg       0.00      0.00      0.00       3.0
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
